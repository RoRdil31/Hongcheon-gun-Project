# %% [markdown]
# <a href="https://colab.research.google.com/github/RoRdil31/Hongcheon-gun-Project/blob/main/%ED%99%8D%EC%B2%9C%EA%B5%B0_%EA%B3%B5%EB%AA%A8%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library setting.

# %%
#!pip install koreanize-matplotlib
import koreanize_matplotlib
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

color = sns.color_palette('pastel')
plt.rc('font',family="Malgun Gothic")
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# !apt-get update -qq
# !apt-get install fonts-nanum -qq

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_prop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = font_prop.get_name()
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123599 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=UserWarning, module="matplotlib.font_manage")

# %%
# %pwd
# Out:
# '/root'

# %%
# %ls
# Out:
# '구조 종별 신고 재난 데이터 2020-2022(홍천).cell'   local_file.xlsx

# %%
# %cd /content
# Out:
# /content

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# # Data Upload and Preprocessing

# %%
# url = 'https://github.com/RoRdil31/Hongcheon-gun-Project.git/구조종별신고재난데이터20202022홍천.xlsx'

# import requests

# response = requests.get(url)
# with open('local_file.xlsx','wb') as f:
#   f.write(response.content)

df = pd.read_excel('구조종별신고재난데이터20202022홍천.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4394 entries, 0 to 4393
# Data columns (total 58 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   재난구조보고서번호  4394 non-null   object
#  1   사고원인       4238 non-null   object
#  2   처리결과구분명    4394 non-null   object
#  3   신고일자       4394 non-null   int64
#  4   신고시각       4394 non-null   int64
#  5   신고연도       4394 non-null   int64
#  6   계절구분명      2998 non-null   object
#  7   분기구분       2998 non-null   float64
#  8   신고월        4394 non-null   int64
#  9   신고일        4394 non-null   int64
#  10  신고시        4394 non-null   int64
#  11  신고분        4394 non-null   int64
#  12  출동일자       4394 non-null   int64
#  13  출동시각       4394 non-null   int64
#  14  출동연도       4394 non-null   int64
#  15  출동월        4394 non-null   int64
#  16  출동일        4394 non-null   int64
#  17  출동시        4394 non-null   int64
#  18  출동분        4394 non-null   int64
# ...

# %%
df.shape
# Out:
# (4394, 58)

# %% [markdown]
# ## Object Data

# %%
df.describe(include='object')
# Out:
#                 재난구조보고서번호   사고원인 처리결과구분명 계절구분명  현장도착시각  구조완료시각   시도명  시군구명  \
# count                4394   4238    4394  2998    4394    4394  4394  4394
# unique               4393    146      19     4    1637     997     1     1
# top     20214208202S00924  기타 사고    안전조치    여름  000nan  000nan   강원도   홍천군
# freq                    2    435    2109  1369      28     345  4394  4394
#
#         읍면동명 읍면동구분명 사고장소명 사고장소세부명   소방서명      서센터명    소방지역대명
# count   4394   4394  4394    4394   3250      2429       821
# unique    10      2   116     195      7        31        10
# top      홍천읍      면  단독주택    단독주택  홍천소방서  홍천119구조대  북방119지역대
# freq    1176   3218  1126     941   3130      1030       192

# %% [markdown]
# ### 중복 데이터 제거

# %%
df.loc[df['재난구조보고서번호']=='20214208202S00924']
# Out:
#               재난구조보고서번호    사고원인 처리결과구분명      신고일자    신고시각  신고연도 계절구분명  분기구분  \
# 3238  20214208202S00924  고드름 제거    안전조치  20211228  111100  2021   NaN   NaN
# 3239  20214208202S00924  고드름 제거    안전조치  20211228  111100  2021   NaN   NaN
#
#       신고월  신고일  ...  사고장소세부명  시간단위기온  시간단위강수량  시간단위풍속  시간단위풍향  시간단위습도  \
# 3238   12   28  ...     단독주택    -8.0     10.0     0.0     0.0    78.0
# 3239   12   28  ...     단독주택    -8.0     10.0     0.0     0.0    78.0
#
#       시간단위적설량   소방서명      서센터명  소방지역대명
# 3238     10.0  홍천소방서  홍천119구조대     NaN
# 3239     10.0  홍천소방서  홍천119구조대     NaN
#
# [2 rows x 58 columns]

# %%
dupl_rows = df[df['재난구조보고서번호']=='20214208202S00924'].index
df = df.drop(dupl_rows[1:])
df.describe(include='object')
# Out:
#                 재난구조보고서번호   사고원인 처리결과구분명 계절구분명  현장도착시각  구조완료시각   시도명  시군구명  \
# count                4393   4237    4393  2998    4393    4393  4393  4393
# unique               4393    146      19     4    1637     997     1     1
# top     20204208102S00001  기타 사고    안전조치    여름  000nan  000nan   강원도   홍천군
# freq                    1    435    2108  1369      28     345  4393  4393
#
#         읍면동명 읍면동구분명 사고장소명 사고장소세부명   소방서명      서센터명    소방지역대명
# count   4393   4393  4393    4393   3249      2428       821
# unique    10      2   116     195      7        31        10
# top      홍천읍      면  단독주택    단독주택  홍천소방서  홍천119구조대  북방119지역대
# freq    1175   3218  1125     940   3129      1029       192

# %% [markdown]
# ### Nan Data 제거 or 보류

# %%
df['현장도착시각'].value_counts()
# df[['현장도착시각','구조완료시각']].value_counts()
# Out:
# 현장도착시각
# 000nan    28
# 125600    13
# 142000    12
# 131600    12
# 151400    11
#           ..
# 234600     1
# 80700      1
# 1913       1
# 194100     1
# 215700     1
# Name: count, Length: 1637, dtype: int64

# %% [markdown]
# ## Number Data

# %%
df.describe()
# Out:
#                신고일자           신고시각         신고연도         분기구분          신고월  \
# count  4.393000e+03    4393.000000  4393.000000  2998.000000  4393.000000
# mean   2.020928e+07  137331.277032  2020.852493     2.636424     7.408832
# std    8.006015e+03   44558.796942     0.804192     0.951914     2.740929
# min    2.020010e+07     300.000000  2020.000000     1.000000     1.000000
# 25%    2.020082e+07  104800.000000  2020.000000     2.000000     7.000000
# 50%    2.021073e+07  135700.000000  2021.000000     3.000000     8.000000
# 75%    2.022011e+07  170100.000000  2022.000000     3.000000     9.000000
# max    2.022123e+07  235900.000000  2022.000000     4.000000    12.000000
#
#                신고일          신고시          신고분          출동일자           출동시각  \
# count  4393.000000  4393.000000  4393.000000  4.393000e+03    4393.000000
# mean     15.570225    13.456180    28.901206  2.020928e+07  137689.392215
# std       8.914114     4.452333    17.465599  8.006014e+03   44506.065994
# ...

# %%
df.isnull().sum()
# Out:
# 재난구조보고서번호       0
# 사고원인          156
# 처리결과구분명         0
# 신고일자            0
# 신고시각            0
# 신고연도            0
# 계절구분명        1395
# 분기구분         1395
# 신고월             0
# 신고일             0
# 신고시             0
# 신고분             0
# 출동일자            0
# 출동시각            0
# 출동연도            0
# 출동월             0
# 출동일             0
# 출동시             0
# 출동분             0
# 현장도착일자         28
# 현장도착시각          0
# 현장도착연도         28
# 현장도착월          28
# 현장도착일          28
# 현장도착시          28
# 현장도착분          28
# 구조완료일자        345
# 구조완료시각          0
# 구조완료연도        345
# 구조완료월         345
# 구조완료일         345
# 구조완료시         345
# 구조완료분         345
# 귀소일자            0
# 귀소시각            0
# 귀소연도            0
# 귀소월             0
# 귀소일             0
# 귀소시             0
# 귀소분             0
# 시도명             0
# 시군구명            0
# 읍면동명            0
# 읍면동구분명          0
# 위치정보X        1330
# 위치정보Y        1330
# 현장소방서거리         0
# 사고장소명           0
# 사고장소세부명         0
# 시간단위기온       1144
# ...
